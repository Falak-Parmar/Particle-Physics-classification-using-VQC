# %% [markdown]
# # QML Baseline (Paper-Aligned)
# This notebook reproduces the classical baseline from the VQC paper.

# %%
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

# %%
# Load dataset (adjust path)
file_path = "../data/HIGGS.csv.gz"
data = pd.read_csv(file_path, header=None, compression='gzip', nrows=5000)

data
# Out:
#        0         1         2         3         4         5         6   \
# 0     1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202
# 1     1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531
# 2     1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875
# 3     0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066
# 4     1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466
# ...   ...       ...       ...       ...       ...       ...       ...
# 4995  1.0  0.284396  1.928404  0.052019  1.888852  1.003629  0.906087
# 4996  1.0  1.517329 -0.218223 -1.491711  0.985417  1.528231  0.903797
# 4997  0.0  2.635514  0.295058 -1.045048  2.472771 -0.723998  1.982105
# 4998  1.0  2.014747 -0.459767  0.973088  1.126357  0.679822  0.795975
# 4999  0.0  0.790965  0.796652  0.013178  0.266051 -1.041734  0.850390
#
#             7         8         9   ...        19        20        21  \
# ...

# %%
corr = data.corr(numeric_only=True)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, cmap='coolwarm', annot=False, fmt=".2f")
plt.title("Correlation Matrix of HIGGS Dataset")
plt.show()

# %%
# Labels
y = data.iloc[:, 0]
y = y.replace({0: -1, 1: 1})

# Select ONLY 2 features (approximation of paper)
# X = data.iloc[:, [4, 6]]  # choose any 2 features

# X = data.iloc[:, [22, 23]]

# %%
corr_with_label = data.corr()[0].abs().sort_values(ascending=False)
top = corr_with_label.index[1:10]
print(top)
# Out:
# Index([26, 28, 4, 27, 1, 13, 6, 11, 25], dtype='int64')

# %%
f1 = top[0]
for f2 in top[1:]:
    if abs(data.corr().loc[f1, f2]) < 0.3:
        break

X = data[[f1, f2]]

print(f1, f2)
# Out:
# 26 4

# %%
# correlations = data.corr()[0].abs().sort_values(ascending=False)
# top_features = correlations.index[1:3]
# X = data[top_features]

# print(X.shape, y.shape)

# %%
# Scale features to [0, pi]
scaler = MinMaxScaler(feature_range=(0, np.pi))
X_scaled = scaler.fit_transform(X)

# %%
# Train / Val / Test split (60/20/20)
X_temp, X_test, y_temp, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, random_state=42)

print("Train:", X_train.shape)
print("Val:", X_val.shape)
print("Test:", X_test.shape)
# Out:
# Train: (3000, 2)
# Val: (1000, 2)
# Test: (1000, 2)

# %%
# Classical baseline model (paper-aligned)
model = MLPClassifier(
    hidden_layer_sizes=(3,),
    activation='relu',
    solver='sgd',
    learning_rate_init=0.01,
    batch_size=32,
    max_iter=30,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# MLPClassifier(batch_size=32, hidden_layer_sizes=(3,), learning_rate_init=0.01,
#               max_iter=30, random_state=42, solver='sgd')

# %%
# Validation performance
val_preds = model.predict(X_val)
val_probs = model.predict_proba(X_val)[:, 1]

val_acc = accuracy_score(y_val, val_preds)
val_auc = roc_auc_score(y_val, val_probs)

print("Validation Accuracy:", val_acc)
print("Validation ROC-AUC:", val_auc)
# Out:
# Validation Accuracy: 0.565
# Validation ROC-AUC: 0.5904761904761905

# %%
# Test performance
test_preds = model.predict(X_test)
test_probs = model.predict_proba(X_test)[:, 1]

test_acc = accuracy_score(y_test, test_preds)
test_auc = roc_auc_score(y_test, test_probs)

print("Test Accuracy:", test_acc)
print("Test ROC-AUC:", test_auc)
# Out:
# Test Accuracy: 0.601
# Test ROC-AUC: 0.5960497268728147

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test, test_probs)

plt.figure()
plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Baseline NN)")
plt.show()

# %% [markdown]
# ----

# %%
import pennylane as qml
from pennylane import numpy as np

dev = qml.device("default.qubit", wires=2)

# %%
@qml.qnode(dev)
def circuit(x, weights):
    # --- State preparation (angle encoding) ---
    for i in range(2):
        qml.RY(x[i], wires=i)

    # --- Model circuit (2 layers) ---
    for l in range(3):
        for i in range(2):
            qml.Rot(weights[l, i, 0],
                    weights[l, i, 1],
                    weights[l, i, 2],
                    wires=i)

        # Entanglement
        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[1, 0])

    # --- Measurement ---
    return qml.expval(qml.PauliZ(0))

# %%
def model(x, weights, bias):
    return circuit(x, weights) + bias

# %%
def loss(weights, bias, X, Y):
    preds = [model(x, weights, bias) for x in X]
    return np.mean((Y - np.array(preds))**2)

# %%
np.random.seed(42)

weights = np.random.randn(3, 2, 3) * 0.1  # (layers, qubits, params)
bias = np.array(0.0)

# %%
opt = qml.GradientDescentOptimizer(stepsize=0.01)

# %%
epochs = 30
batch_size = 32

X_train_np = np.array(X_train)
y_train_np = np.array(y_train)

for epoch in range(epochs):
    for i in range(0, len(X_train_np), batch_size):
        X_batch = X_train_np[i:i+batch_size]
        y_batch = y_train_np[i:i+batch_size]

        weights, bias = opt.step(
            lambda w, b: loss(w, b, X_batch, y_batch),
            weights, bias
        )

    if epoch % 5 == 0:
        current_loss = loss(weights, bias, X_train_np, y_train_np)
        print(f"Epoch {epoch}: Loss = {current_loss:.4f}")
# Out:
# Epoch 0: Loss = 0.9681
# Epoch 5: Loss = 0.9594
# Epoch 10: Loss = 0.9544
# Epoch 15: Loss = 0.9522
# Epoch 20: Loss = 0.9514
# Epoch 25: Loss = 0.9511

# %%
def predict(X, weights, bias):
    return np.array([model(x, weights, bias) for x in X])

# Predictions
y_scores = predict(np.array(X_test), weights, bias)

# Convert to labels
y_pred = np.where(y_scores > 0, 1, -1)

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_scores)

print("VQC Accuracy:", acc)
print("VQC ROC-AUC:", auc)
# Out:
# VQC Accuracy: 0.605
# VQC ROC-AUC: 0.6075589358513671

# %%
fpr, tpr, _ = roc_curve(y_test, y_scores)

import matplotlib.pyplot as plt

plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (VQC)")
plt.show()
